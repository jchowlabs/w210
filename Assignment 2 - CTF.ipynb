# %%
#####################
# For Your Eyes Only
#####################

from socket import *
s = socket(AF_INET, SOCK_STREAM)
s.connect(("w210.network",8001))

s.send(b"But not at St. Moritz")
data = s.recv(10000)
s.close()

# %%
########################
# Roman Reverse Captcha
########################

import time
import re
from socket import *
s = socket(AF_INET, SOCK_STREAM)
s.connect(("w210.network", 8002))

s.send(b"16\n")
s.send(b"65536\n")
s.send(b"4194304\n")

while True:
    
    data = s.recv(1024).decode()
    identity_index = data.find("identity")
    hiccup_index = data.find("hiccups")
    print(data)
    
    if identity_index > 193:
        
        digit = re.findall(r'\d+', data)
        
        element1 = digit[0]
        element2 = digit[1]
        element3 = digit[2]
        element4 = digit[3]
        element5 = digit[4]
        element6 = digit[5]
        
        equation1 = int(element1) + int(element2)
        equation2 = int(element3) + int(element4)
        equation3 = int(element5) + int(element6)
        
        message4 = str(equation1) + '\n'
        message5 = str(equation2) + '\n'
        message6 = str(equation3) + '\n'
        
        s.send(message4.encode())
        s.send(message5.encode())
        s.send(message6.encode())
        
    if hiccup_index > 38:
        
        fragments = []
        done = False
        
        while (not done):
            chunk = s.recv(1024).decode()
            if ('\n' in chunk):
                done = True
                break
            else:
                fragments.append(chunk)          
            
        message = "".join(fragments)
        words = message.split()
        elem1 = words[1]
        elem2 = words[3]
        equation4 = int(elem1) + int(elem2)
        msg1 = str(equation4) + '\n'
        s.send(msg1.encode())
        
        # Handling for equation 2
        fragments = []
        done = False
        chunk = ""
        message = ""
        words = ""
        elem1 = ""
        elem2 = ""
        msg1 = ""
        
        while (not done):
            chunk = s.recv(1024).decode()
            if ('\n' in chunk):
                done = True
                break
            else:
                fragments.append(chunk)          

        message = chunk
        words = message.split()
        elem1 = words[1]
        elem2 = words[3]
        equation4 = int(elem1) + int(elem2)
        msg1 = str(equation4) + '\n'
        s.send(msg1.encode())
        
        # Handling for equation 3
        fragments = []
        done = False
        chunk = ""
        message = ""
        words = ""
        elem1 = ""
        elem2 = ""
        msg1 = ""
        
        while (not done):
            chunk = s.recv(1024).decode()
            if ('\n' in chunk):
                done = True
                print("")
                break
            else:
                fragments.append(chunk)  
                
        message = chunk
        words = message.split()
        elem1 = words[1]
        elem2 = words[3]
        equation4 = int(elem1) + int(elem2)
        msg1 = str(equation4) + '\n'
        s.send(msg1.encode())
        
        # Handling for equation 4
        fragments = []
        done = False
        chunk = ""
        message = ""
        words = ""
        elem1 = ""
        elem2 = ""
        msg1 = ""
        
        while (not done):
            chunk = s.recv(1024).decode()
            if ('\n' in chunk):
                done = True
                break
            else:
                fragments.append(chunk)          
            
        message = chunk
        words = message.split()
        elem1 = words[1]
        elem2 = words[3]
        equation4 = int(elem1) + int(elem2)
        msg1 = str(equation4) + '\n'
        s.send(msg1.encode())

        break
        
s.close()
